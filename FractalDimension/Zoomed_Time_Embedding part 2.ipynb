# %%
import ExonExonData as eed
import pathlib
cwd = pathlib.Path.cwd()
import pandas
import pickle
from Heatmaps import heatmapv2 as heatmap
from Heatmaps import _undigitize_seq as undigit
from TimeEmbedding import time_embedding_1D as te_1d
from ExonExonPlots import plots_v2
from TimeEmbedding import time_embedding_v2
from TimeEmbedding import matplotfigure
from RecoverSeq import recover_seq
import gc

# %%
e_data_file = cwd.parent / "Data_Files" / "Primates" / "Homo_sapiens" / "EI_Data" / "E_Data_dict.pkl"
i_data_file = cwd.parent / "Data_Files" / "Primates" / "Homo_sapiens" / "EI_Data" / "I_Data_dict.pkl"

k_label = 2
steps = 16
delta = 1 / steps
inches = 5

# In case we don't want to start at the center.
x_start = 7*delta
x_stop = 8*delta
x_steps = steps - 7
y_start = 13*delta
y_stop = 14*delta
y_steps = steps - 13

# %%
def limit(data: dict, x_lim: list, y_lim: list):
    '''
    Takes in the dict. This will limit the xy cords.
    The reason for doing this: instead of doing a limit on the same data set 16 times (for a total of 96 minutes)
    I can do it once then filter the data as needed each time.
    '''
    filtered_data = {}
    for key, xy in data.items():
        xy = xy[(x_lim[1] >= xy[:, 0]) & (xy[:, 0] >= x_lim[0])]
        xy = xy[(y_lim[1] >= xy[:, 1]) & (xy[:, 1] >= y_lim[0])]

        filtered_data[key] = xy

    return filtered_data

# %%
with open(e_data_file, "rb") as file:
    e_frame = pickle.load(file)

with open(i_data_file, "rb") as file:
    i_frame = pickle.load(file)

# %%
for _ in range(0, x_steps):
    x_box = [x_start, x_stop]
    for _ in range(0, y_steps):
        y_box = [y_start, y_stop]

        x_seq = recover_seq(x_box[1], k = k_label)
        y_seq = recover_seq(y_box[1], k = k_label)

        # print([x_start, x_stop], x_seq[0], [y_start, y_stop], y_seq[0])

        temp_e_frame = limit(e_frame, x_box, y_box)
        temp_i_frame = limit(i_frame, x_box, y_box)

        exon_file_path = cwd / "TE_Images_ForPaper" / "TE_Zoom" / "Exon" / f"{x_seq[0]}"
        exon_file_path.mkdir(parents = True, exist_ok = True)
        intron_file_path = cwd / "TE_Images_ForPaper" / "TE_Zoom" / "Intron" / f"{x_seq[0]}"
        intron_file_path.mkdir(parents = True, exist_ok = True)

        # print(file_path / "Exon" / f"{x_seq[0]}_{y_seq[0]}_exon.png")
        # print(file_path / "Exon" / f"{x_seq[0]}_{y_seq[0]}_intron.png")

        matplotfigure(temp_e_frame, dir = exon_file_path, file_name = f"{x_seq[0]}_{y_seq[0]}_exon.png", inches = inches,
        default_title = False, title = "", x_title = f"{x_seq[0]}", y_title = f"{y_seq[0]}")
        matplotfigure(temp_i_frame, dir = intron_file_path, file_name = f"{x_seq[0]}_{y_seq[0]}_intron.png", inches = inches,
        default_title = False, title = "", x_title = f"{x_seq[0]}", y_title = f"{y_seq[0]}")

        y_start = y_stop
        y_stop += delta
        del temp_e_frame
        del temp_i_frame
        gc.collect()
    else:
        y_start = 0
        y_stop = delta
        y_steps = steps
        gc.collect()

    x_start = x_stop
    x_stop += delta
    x_steps = steps
    gc.collect()


# aa_eframe = limit(e_frame, aa_box[0], aa_box[1])
# aa_iframe = limit(i_frame, aa_box[0], aa_box[1])
# matplotfigure(aa_eframe, dir = aa_eof.parent, file_name = aa_eof.name)
# matplotfigure(aa_iframe, dir = aa_iof.parent, file_name = aa_iof.name)
# Out:
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\GC\GC_CG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\GC\GC_CG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\GC\GC_CT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\GC\GC_CT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\GC\GC_CC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\GC\GC_CC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_AA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_AA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_AG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_AG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_AT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_AT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_AC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_AC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_GA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_GA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_GG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_GG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_GT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_GT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_GC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_GC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_TA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_TA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_TG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_TG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_TT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_TT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_TC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_TC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_CA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_CA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_CG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_CG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_CT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_CT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TA\TA_CC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TA\TA_CC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_AA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_AA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_AG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_AG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_AT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_AT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_AC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_AC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_GA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_GA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_GG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_GG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_GT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_GT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_GC_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_GC_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_TA_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_TA_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_TG_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_TG_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_TT_exon.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Intron\TG\TG_TT_intron.png
# Output image to d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\TE_Zoom\Exon\TG\TG_TC_exon.png
