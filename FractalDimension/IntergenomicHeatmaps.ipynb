# %%
import pandas
import numpy as np
import os
import pathlib
cwd = pathlib.Path.cwd()
import MomentCalculations as MC
import Heatmaps as heat
import TimeEmbedding as TE
import pickle
import GeneClass as Gene
from typing import Tuple
from typing import Generator

# %%
master = pandas.read_pickle(cwd / "HS_Dicts_EF" / "Inter_6mer.pkl")
print("Loaded master")
# Out:
# Loaded master

# %%
print(type(master))
# Out:
# <class 'dict'>

# %%
print(list(master.keys())[0])
print(master[list(master.keys())[0]])
# Out:
# AAAAAA
# ...

# %%
colors: list = ['green', 'orange', 'orangered', 'red']
bounds: list = [0, 0.452, 1.45, 2.36, 3.2] # 0.98

heat.heatmapv2(master, fileoutput=cwd / "TE_Images_ForPaper" / "Heatmaps" / "EA" / "InterGenomic.png", colors=colors, bounds=bounds)
# Out:
# Output file to
# 	d:\Coding\Thesis\FractalDimension\TE_Images_ForPaper\Heatmaps\EA\InterGenomic.png
